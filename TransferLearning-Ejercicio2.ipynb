# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelamda/TL-tutorial/blob/master/TransferLearning-Ejercicio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 2. Transfer Learning sobre Abejas Polinizadas
#
# Ejercicio 2 del tutorial de Transfer Learning.
#
# GPT2: Diseño y Gestión de Proyectos en Data Science II.
# [Máster en Data Science y Big Data](http://masterds.es/) de la [Universidad de Sevilla](http://www.us.es).
#
# 25/06/2020. Profesor: [Miguel Ángel Martínez del Amor](http://www.cs.us.es/~mdelamor)
#
# ![abeja](https://raw.githubusercontent.com/miguelamda/DL/master/Ejercicios/img/abeja.jpg)
#
# En este ejercicio vamos a poner a prueba los conceptos adquiridos sobre Transfer Learning usando este conjunto de datos: [honey bees pollen](https://www.kaggle.com/ivanfel/honey-bee-pollen). En este conjunto de imágenes se grabó con cámara de vídeo a abejas transportando y sin transportar polen. Se extrajo imágenes y se recortó para que el conjunto de datos solo contenga imágenes de abejas con y sin polen. La estructura de directorios que se proporciona en el taller ya viene dispuesta dividiendo el conjunto de test y de train.
#
# Veamos una muestra de las imágenes del dataset. No evalúes la siguiente celda, para no perder la imagen.

# %%
#class_names=list(['Non-Pollen','Pollen'])
#plot_images(images=X_train[0:9], cls_true=Y_train[0:9], smooth=True)

# %% [markdown]
# Realiza los siguientes apartados.
#
# ## 1. Descarga del dataset
#
# Tan solo evalúa las siguienes celdas para descargar el dataset desde el repositorio del tutorial, el cual debería aparecer en la carpeta `data`. Finalmente, descomprime el fichero zip, y asigna las variables con la ruta a las carpetas train y test.

# %%
# Descarga el repositorio (el cual incluye el dataset)
import os
work_dir = "/content/TL-tutorial/"
if os.getcwd() != work_dir:
    # !git clone https://github.com/miguelamda/TL-tutorial.git
os.chdir(work_dir)

# %%
# Accede a la carpeta para descomprimir el dataset adaptado para Keras
os.chdir("data")
# !unzip bees.zip
os.chdir("..")
# !ls data/bees

# %%
# Estos son los directorios de los datos para que puedas usarlos desde Keras
train_dir = "data/bees/train"
test_dir = "data/bees/test"

# %% [markdown]
# ## 2. Entrenamiento de un modelo nuevo
#
# Entrena un modelo desde cero sobre este conjunto. Puedes usar la red convolucional para datasets pequeños como la usada [aquí](https://github.com/miguelamda/DL/blob/master/5.%20Redes%20Convolucionales/Practica5.2.%20CNN%20con%20datasets%20peque%C3%B1os.ipynb). ¿Qué precisión obtienes? Es posible que tengas que adaptar algunas funciones auxiliares aquí definidas.

# %% [markdown]
# ## 3. Transfer Learning completo
#
# Haz transfer learning con VGG16, y después fine tuning. ¿Mejora la precisión?

# %% [markdown]
# ## 4. Transfer Learning parcial
#
# Haz transfer Learning y fine tuning con VGG16 desde tan solo la primera capa. ¿Mejora la precisión?
